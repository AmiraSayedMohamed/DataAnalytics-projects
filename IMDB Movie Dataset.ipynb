# %% [markdown]
# https://www.kaggle.com/PromptCloudHQ/imdb-data

# %% [markdown]
# # Steps for Data Analysis:
#
#
# ---------------------------------
#   ##  1.Understand the Dataset:
# -------------------------
#
#         - Review each column in the dataset to understand its meaning.
#         - Identify the type of data in each column (e.g., numerical, categorical, text).
#    ----------------
#  ## 2.Data Cleaning:
#  ------------------
#
#     - Handle missing values (e.g., Revenue and Metascore have NaN values).
#     - Correct data types if needed (e.g., ensure 'Year' is an integer, 'Revenue' is a float).
#     - Remove any duplicates if present.
#
# ---------------------------------
#  ## 3.Exploratory Data Analysis (EDA):
# --------------------------------
#
#    ### Descripive Statistics:
#     - Summarize numerical data (mean, median, mode, etc.).
#     - Count unique values in categorical columns like Genre, Director, and Actors.
#    ### Correlations:
#     - Analyze the correlation between numerical variables (e.g., Rating vs. Revenue).
#    ### Outliers:
#     - Identify and investigate outliers in numerical columns like Revenue and Votes.
#
# --------------------------------------------------
#  ## 4.Formulate Questions:
#  -----------------------------
#
#    ### General Questions:
#     - What are the most common genres?
#     - Which directors and actors are most frequent in the top-ranked movies?
#     - What is the average runtime of movies?
#    ### Performance-Related Questions:
#     - How does movie rating correlate with revenue?
#     - Is there a relationship between runtime and rating?
#     - Which years produced the highest-grossing movies?
#    ### Trend Analysis:
#     - How have movie ratings changed over the years?
#     - What genres have the highest average revenue?
#
# -----------------------
#    ## 5.Extract Insights:
# -----------------------
#
#     - Determine the top genres and their performance metrics (e.g., average rating and revenue).
#     - Identify directors who consistently produce high-revenue movies.
#     - Analyze the effect of runtime on a movie’s rating and revenue.
#     - Evaluate the most profitable years and the trends in movie production.
#
# ----------------------------------------------------------------------------------
#   ## 6. Visualization (Graphs to Appear in Dashboard):
# -----------------------------------------------------
#
#    ### Histogram:
#     - Distribution of movie ratings.
#     - Distribution of revenues.
#     - Distribution of runtimes.
#    ### Bar Chart:
#     - Count of movies by genre.
#     - Average revenue per genre.
#     - Top directors based on average rating and revenue.
#    ### Scatter Plot:
#     - Rating vs. Revenue.
#     - Runtime vs. Rating.
#    ### Line Plot:
#     - Trends of movie ratings over the years.
#     - Trends of average revenue over the years.
#    ### Box Plot:
#     - Distribution of ratings and revenues by genre.
#    ### Heatmap:
#     - Correlation matrix of numerical variables (Rating, Votes, Revenue, Metascore).
#
#
#   ## 7.Dashboard Layout Using Subplots:
#
#    ### Top Row:
#         Left: Bar chart showing the count of movies by genre.
#         Right: Scatter plot of Rating vs. Revenue.
#    ### Middle Row:
#         Left: Histogram of movie ratings.
#         Right: Line plot showing trends of movie ratings over the years.
#    ### Bottom Row:
#     Left: Box plot showing the distribution of revenue by genre.
#     Right: Heatmap of the correlation matrix.
#
#
# # Insights to Extract:
#   ## Genre Popularity:
#        Identify which genres dominate the dataset in terms of both count and performance metrics like rating and revenue.
#   ## Director Impact:
#       Determine which directors are associated with higher ratings and revenue.
#   ## Yearly Trends:
#       Understand how the film industry has evolved in terms of movie quality (ratings) and profitability (revenue).
#   ## Runtime Analysis:
#       Evaluate whether longer or shorter movies tend to have higher ratings or revenue.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('IMDB-Movie-Data.csv')

# %% [markdown]
# # 1.Display Top 10 Rows of the Dataset

# %%
data.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %% [markdown]
# # 2.Check Last 10 Rows of The Dataset

# %%
data.tail(10)
# Out:
#      Rank                           Title                     Genre  \
# 990   991  Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                Taare Zameen Par        Drama,Family,Music
# 992   993            Take Me Home Tonight      Comedy,Drama,Romance
# 993   994        Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                       Project X                    Comedy
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 996   997                 Hostel: Part II                    Horror
# 997   998          Step Up 2: The Streets       Drama,Music,Romance
# 998   999                    Search Party          Adventure,Comedy
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description            Director  \
# 990  An origins story centered on the centuries-old...  Patrick Tatopoulos
# ...

# %% [markdown]
# # 3.Find Shape of our dataset (Number of Rows and number of columns)

# %%
data.shape
# Out:
# (1000, 12)

# %%
print("Number of Rows", data.shape[0])
print("Number of Columns", data.shape[1])
# Out:
# Number of Rows 1000
# Number of Columns 12

# %% [markdown]
# # 4.Getting information abour Our dataset like Total number of Rows, Columns , DataTypes of Each Columnd And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %% [markdown]
# # 5.Check Missing Values in The Dataset

# %%
print("Any Missing value?", data.isnull().values.any())
# Out:
# Any Missing value? True

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
# Ger percentage of the missing value in columns
per_missing = data.isnull().sum() * 100 / len(data)
per_missing
# Out:
# Rank                   0.0
# Title                  0.0
# Genre                  0.0
# Description            0.0
# Director               0.0
# Actors                 0.0
# Year                   0.0
# Runtime (Minutes)      0.0
# Rating                 0.0
# Votes                  0.0
# Revenue (Millions)    12.8
# Metascore              6.4
# dtype: float64

# %% [markdown]
# # 6.Drop All Missing Values

# %%
data = data.dropna(axis=0)

# %% [markdown]
# # 7. Check For Duplicate Data

# %%
dup_data = data.duplicated().any()

# %%
print("Are there any duplicated values?", dup_data)
# Out:
# Are there any duplicated values? False

# %%
# but if there any duplicate values use this
data = data.drop_duplicates()
data
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# # 8.Get Overall Statistics About The DataFrame

# %%
data.describe()
# Out:
#               Rank        Year  Runtime (Minutes)      Rating         Votes  \
# count   838.000000   838.00000         838.000000  838.000000  8.380000e+02
# mean    485.247017  2012.50716         114.638425    6.814320  1.932303e+05
# std     286.572065     3.17236          18.470922    0.877754  1.930990e+05
# min       1.000000  2006.00000          66.000000    1.900000  1.780000e+02
# 25%     238.250000  2010.00000         101.000000    6.300000  6.127650e+04
# 50%     475.500000  2013.00000         112.000000    6.900000  1.368795e+05
# 75%     729.750000  2015.00000         124.000000    7.500000  2.710830e+05
# max    1000.000000  2016.00000         187.000000    9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          838.000000  838.000000
# mean            84.564558   59.575179
# std            104.520227   16.952416
# min              0.000000   11.000000
# 25%             13.967500   47.000000
# 50%             48.150000   60.000000
# ...

# %%
# We check the outliers of every feature using boxplot
plt.figure(figsize=(15,7))
sns.boxplot(data=data)
# Out:
# <Axes: >

# %% [markdown]
# # Remove Outliers

# %%
# Select only the numeric columns
numeric_df = data.select_dtypes(include=[float, int])

for col in numeric_df:
    q1 = data[col].quantile(0.25)
    q3 = data[col].quantile(0.75)
    iqr = q3 - q1
    upper_limit = q3 + (1.5 * iqr)
    lower_limit = q1 - (1.5 * iqr)
    new_df2 = data.loc[(data[col] <= upper_limit) & (data[col] >= lower_limit)]
print('before removing outliers: ', len(data))
print('after removing outliers: ', len(new_df2))
print('outliers:', len(data)-len(new_df2))
data = new_df2zzzzzzz
# Out:
# before removing outliers:  838
# after removing outliers:  838
# outliers: 0

# %% [markdown]
# # 9.Display Title of The movie Having Runtime >= 180 Minutes

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data[data['Runtime (Minutes)']>=180]
# Out:
#      Rank                    Title                   Genre  \
# 82     83  The Wolf of Wall Street  Biography,Comedy,Crime
# 88     89        The Hateful Eight     Crime,Drama,Mystery
# 311   312           La vie d'Adèle           Drama,Romance
#
#                                            Description             Director  \
# 82   Based on the true story of Jordan Belfort, fro...      Martin Scorsese
# 88   In the dead of a Wyoming winter, a bounty hunt...    Quentin Tarantino
# 311  Adèle's life is changed when she meets Emma, a...  Abdellatif Kechiche
#
#                                                 Actors  Year  \
# 82   Leonardo DiCaprio, Jonah Hill, Margot Robbie,M...  2013
# 88   Samuel L. Jackson, Kurt Russell, Jennifer Jaso...  2015
# 311  Léa Seydoux, Adèle Exarchopoulos, Salim Kechio...  2013
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 82                 180     8.2  865134              116.87       75.0
# ...

# %%
data[data['Runtime (Minutes)']>=180]['Title']
# Out:
# 82     The Wolf of Wall Street
# 88           The Hateful Eight
# 311             La vie d'Adèle
# Name: Title, dtype: object

# %% [markdown]
# # 10.In Which Year There was the highest Average Voting

# %%
# Display first all columns we have to know which the name the vote column
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.groupby('Year')['Votes'].mean()
# Out:
# Year
# 2006    277232.219512
# 2007    266530.704545
# 2008    266580.145833
# 2009    267180.577778
# 2010    261082.929825
# 2011    259254.736842
# 2012    290861.483871
# 2013    225531.892857
# 2014    211926.881720
# 2015    129512.651376
# 2016     68437.823232
# Name: Votes, dtype: float64

# %%
data.groupby('Year')['Votes'].mean().sort_values(ascending=False)
# Out:
# Year
# 2012    290861.483871
# 2006    277232.219512
# 2009    267180.577778
# 2008    266580.145833
# 2007    266530.704545
# 2010    261082.929825
# 2011    259254.736842
# 2013    225531.892857
# 2014    211926.881720
# 2015    129512.651376
# 2016     68437.823232
# Name: Votes, dtype: float64

# %%
# Create the bar plot with a predefined palette
sns.barplot(x='Year', y='Votes', data=data, hue='Year', palette='bright', dodge=False)
plt.title("Votes By Year")
plt.legend([],[], frameon=False)  # Hide the legend
plt.show()

# %% [markdown]
#                     ---------------------------------------------------
#                      we can see that 2012 has the highes average voting
#                      --------------------------------------------------

# %% [markdown]
# # 11.In Which Year There Was The Highest Average Revenue?

# %%
# to show the names of columns to know the name of the revenue columns
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.groupby('Year')['Revenue (Millions)'].mean().sort_values(ascending=False)
# Out:
# Year
# 2009    115.742000
# 2012    110.103065
# 2010    105.081579
# 2008     97.525417
# 2011     93.703333
# 2007     93.074091
# 2013     88.084643
# 2006     87.255610
# 2014     85.433656
# 2015     80.725596
# 2016     55.566111
# Name: Revenue (Millions), dtype: float64

# %% [markdown]
#         --------------------------------------------
#         we can see that 2009 has the highest Revenue
#         -------------------------------------------

# %%
top10_len = data.nlargest(10, 'Revenue (Millions)')[['Title', 'Revenue (Millions)']].set_index('Title')
top10_len
# Out:
#                                             Revenue (Millions)
# Title
# Star Wars: Episode VII - The Force Awakens              936.63
# Avatar                                                  760.51
# Jurassic World                                          652.18
# The Avengers                                            623.28
# The Dark Knight                                         533.32
# Rogue One                                               532.17
# Finding Dory                                            486.29
# Avengers: Age of Ultron                                 458.99
# The Dark Knight Rises                                   448.13
# The Hunger Games: Catching Fire                         424.65

# %%
plt.hist(data['Revenue (Millions)'], bins=5, edgecolor='black')
plt.xlabel('Revenue (Millions)')
plt.ylabel('count')
plt.title('Revenue Distribution')
plt.show()

# %% [markdown]
# # 12.Find the Average Rating For Each Director

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.groupby('Director')['Rating'].mean().sort_values(ascending=False)
# Out:
# Director
# Christopher Nolan                   8.68
# Olivier Nakache                     8.60
# Makoto Shinkai                      8.60
# Florian Henckel von Donnersmarck    8.50
# Aamir Khan                          8.50
#                                     ...
# Sam Taylor-Johnson                  4.10
# Joey Curtis                         4.00
# George Nolfi                        3.90
# James Wong                          2.70
# Jason Friedberg                     1.90
# Name: Rating, Length: 524, dtype: float64

# %% [markdown]
# # 13.Display Top 10 Lengthy Movies Title and Runtime

# %%
# 13.Display Top 10 Lengthy Movies Title and Runtime
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
top10_len = data.nlargest(10, 'Runtime (Minutes)')[['Title', 'Runtime (Minutes)']].set_index('Title')
top10_len
# Out:
#                                           Runtime (Minutes)
# Title
# The Hateful Eight                                       187
# The Wolf of Wall Street                                 180
# La vie d'Adèle                                          180
# Cloud Atlas                                             172
# 3 Idiots                                                170
# Interstellar                                            169
# Pirates of the Caribbean: At World's End                169
# The Hobbit: An Unexpected Journey                       169
# The Curious Case of Benjamin Button                     166
# Transformers: Age of Extinction                         165

# %% [markdown]
#                     ---------------------------------------------------
#                     we can see that (Grindhouse) has the largest Runtime
#                     ----------------------------------------------------

# %%
sns.barplot(x='Runtime (Minutes)', y=top10_len.index, data=top10_len)
# Out:
# <Axes: xlabel='Runtime (Minutes)', ylabel='Title'>

# %% [markdown]
# # 14. Display Number of Movies Per Year

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data['Year'].value_counts()
# Out:
# Year
# 2016    198
# 2015    109
# 2014     93
# 2013     84
# 2012     62
# 2011     57
# 2010     57
# 2008     48
# 2009     45
# 2007     44
# 2006     41
# Name: count, dtype: int64

# %%
sns.countplot(x='Year', data=data)
plt.title("Number of Movies Per Year")
plt.show()

# %% [markdown]
#             -----------------------------------------------------------
#                  ( 2016 ) has the Highest number of films (297)
#             -------------------------------------------------------------

# %% [markdown]
# # 15.Find Most Popular Movie Title(Highes Revenue)

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data['Revenue (Millions)'].max()
# Out:
# 936.63

# %%
data[data['Revenue (Millions)'].max()==data['Revenue (Millions)']]['Title']
# Out:
# 50    Star Wars: Episode VII - The Force Awakens
# Name: Title, dtype: object

# %% [markdown]
# ----------------------------------------------------------------
# the movie who has the highes revenue
# Star Wars: Episode VII - The Force Awakens
#
#
#
#
#  -------------------------------------------------------------

# %% [markdown]
# # 16.Display Top 10 Highes Rated Movie Titles And its Directors

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
top10_len=data.nlargest(10, 'Rating')[['Title', 'Rating', 'Director']].set_index('Title')

# %%
top10_len
# Out:
#                        Rating                          Director
# Title
# The Dark Knight           9.0                 Christopher Nolan
# Inception                 8.8                 Christopher Nolan
# Interstellar              8.6                 Christopher Nolan
# Kimi no na wa             8.6                    Makoto Shinkai
# The Intouchables          8.6                   Olivier Nakache
# The Prestige              8.5                 Christopher Nolan
# The Departed              8.5                   Martin Scorsese
# The Dark Knight Rises     8.5                 Christopher Nolan
# Whiplash                  8.5                   Damien Chazelle
# The Lives of Others       8.5  Florian Henckel von Donnersmarck

# %%
sns.barplot(x='Rating', y=top10_len.index, data=top10_len, hue='Director', dodge=False)
plt.legend(bbox_to_anchor=(1.05,1),loc=2)

# %% [markdown]
# -------------------------------------------------------------
# Dark Knight is the highest rated and it's director is (Christopher Nolan)
#
#
# ---------------------------------------------------------------

# %% [markdown]
# # How have movie ratings changed over the years?

# %%
rating = data.groupby('Year')['Rating'].mean()
plt.plot(rating.index, rating.values, marker='o', color='b', linestyle='-')

plt.title('Average Movie Ratings Over the Years', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Average Rating', fontsize=12)
# Show grid and plot
plt.grid(True)
plt.show()

# %% [markdown]
# # 17.Display Top 10 Highest Revenue Movie Titles

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
top_10 = data.nlargest(10, 'Revenue (Millions)')[['Title', 'Revenue (Millions)']].set_index('Title')
top_10
# Out:
#                                             Revenue (Millions)
# Title
# Star Wars: Episode VII - The Force Awakens              936.63
# Avatar                                                  760.51
# Jurassic World                                          652.18
# The Avengers                                            623.28
# The Dark Knight                                         533.32
# Rogue One                                               532.17
# Finding Dory                                            486.29
# Avengers: Age of Ultron                                 458.99
# The Dark Knight Rises                                   448.13
# The Hunger Games: Catching Fire                         424.65

# %%
sns.barplot(x='Revenue (Millions)', y=top_10.index, data=top_10, hue='Title', dodge=False)
plt.title("Top 10 Highes Revenue Movie Titles")
plt.show()

# %% [markdown]
# # 18.Find Average Rating of Movies Year Wise

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.groupby('Year')['Rating'].mean().sort_values(ascending=False)
# Out:
# Year
# 2006    7.143902
# 2007    7.140909
# 2011    6.945614
# 2012    6.933871
# 2009    6.911111
# 2010    6.894737
# 2013    6.832143
# 2014    6.822581
# 2008    6.708333
# 2015    6.674312
# 2016    6.644444
# Name: Rating, dtype: float64

# %% [markdown]
# # 19.Does Rating affect the Revenue

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
sns.scatterplot(x="Rating", y="Revenue (Millions)", data=data)
# Out:
# <Axes: xlabel='Rating', ylabel='Revenue (Millions)'>

# %% [markdown]
# # 20.Classify Movies Based on Rating [Excellent, Good and Average]

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
def rating(rating):
    if rating>=7.0:
        return "Excellent"
    elif rating >=6.0:
        return "Good"
    else:
        return "Average"

# %%
data['rating_cat'] = data['Rating'].apply(rating)

# %%
data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'rating_cat'],
#       dtype='object')

# %%
data['Genre'].dtype
# Out:
# dtype('O')

# %% [markdown]
# # 21.Is there a relationship between runtime and rating?

# %%
sns.scatterplot(x="Rating", y="Runtime (Minutes)", data=data)
# Out:
# <Axes: xlabel='Rating', ylabel='Runtime (Minutes)'>

# %% [markdown]
# # 22.Find Unique Values From Genre

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'rating_cat'],
#       dtype='object')

# %%
data['Genre']
# Out:
# 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 993     Action,Adventure,Horror
# 994                      Comedy
# 996                      Horror
# 997         Drama,Music,Romance
# 999       Comedy,Family,Fantasy
# Name: Genre, Length: 838, dtype: object

# %%
list1=[]
for value in data['Genre']:
    list1.append(value.split(','))

# %%
list1
# Out:
# [['Action', 'Adventure', 'Sci-Fi'],
#  ['Adventure', 'Mystery', 'Sci-Fi'],
#  ['Horror', 'Thriller'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Comedy', 'Drama', 'Music'],
#  ['Action', 'Adventure', 'Biography'],
#  ['Adventure', 'Drama', 'Romance'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Thriller'],
#  ['Biography', 'Drama'],
#  ['Drama', 'Mystery', 'Sci-Fi'],
#  ['Adventure', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Comedy'],
#  ['Drama', 'Thriller'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Comedy'],
# ...

# %%
one_d = []
for item in list1:
    for item1 in item:
        one_d.append(item1)

# %%
one_d
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Mystery',
#  'Sci-Fi',
#  'Horror',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Action',
#  'Adventure',
#  'Biography',
#  'Adventure',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Thriller',
# ...

# %%
uni_list=[]
for item in one_d:
    if item not in uni_list:
        uni_list.append(item)

# %%
uni_list
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Mystery',
#  'Horror',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Drama',
#  'Music',
#  'Biography',
#  'Romance',
#  'History',
#  'Western',
#  'Crime',
#  'War',
#  'Musical',
#  'Sport']

# %%
len(uni_list)
# Out:
# 20

# %% [markdown]
# # 23. How many Films of Each Genre were made ?

# %%
one_d =[]
for item in list1:
    for item1 in item:
        one_d.append(item1)

# %%
one_d
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Mystery',
#  'Sci-Fi',
#  'Horror',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Action',
#  'Adventure',
#  'Biography',
#  'Adventure',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Thriller',
# ...

# %%
from collections import Counter

# %%
Counter(one_d)
# Out:
# Counter({'Drama': 419,
#          'Action': 277,
#          'Comedy': 250,
#          'Adventure': 244,
#          'Thriller': 148,
#          'Crime': 126,
#          'Romance': 120,
#          'Sci-Fi': 107,
#          'Fantasy': 92,
#          'Horror': 87,
#          'Mystery': 86,
#          'Biography': 67,
#          'Family': 48,
#          'Animation': 45,
#          'History': 25,
#          'Music': 15,
#          'Sport': 15,
#          'War': 10,
#          'Musical': 5,
#          'Western': 4})

# %% [markdown]
# ---------------------------------------------------------------------------------------------------
# now we have the answer of these questions:
#
# - The Film has the highest runtime  <<                Grindhouse
# - The Year that has highest average voting <<           2012
# - The year that has the highest revenue <<                2009
# - The director who has the highest rating is <<        Nitesh Tiwari
# - The year that has the largest number of movie published is << 2016
# The film who has the highest revenue was <<   Star Wars: Episode VII - The Force Awakens  and it was (936.63)
#
#  The movie that has the highes rating is << The Dark Knight and  it's director was (Christopher Nolan)
#
# The year that has the highest average raring  is << 2007
#
# The Kind of the largest number of films is drama

# %%
import matplotlib.pyplot as plt

# Assuming 'counter_data' is your Counter object
counter_data = Counter({
        'Drama': 474,
         'Action': 289,
         'Comedy': 268,
         'Adventure': 249,
         'Thriller': 183,
         'Crime': 141,
         'Romance': 131,
         'Sci-Fi': 114,
         'Horror': 108,
         'Mystery': 99,
         'Fantasy': 98,
         'Biography': 71,
         'Family': 50,
         'Animation': 46,
         'History': 28,
         'Music': 16,
         'Sport': 16,
         'War': 12,
         'Western': 6,
         'Musical': 5})

# Extract genres and frequencies
genres = list(counter_data.keys())
frequencies = list(counter_data.values())

# Create the bar chart
plt.figure(figsize=(12, 6))
plt.bar(genres, frequencies, color='blue')
plt.xlabel('Genre')
plt.ylabel('Frequency')
plt.title('Genre Distribution')
plt.xticks(rotation=45)
plt.show()



fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 10))

sns.countplot(x='Year', y='Votes', hue='Year', palette='bright', data=data, ax=axes[0, 0])
axes[0, 0].set_title('Votes By Year')

sns.scatterplot(x='Rating', y='Revenue (Millions)', data=data, ax=axes[0, 1])
axes[0, 1].set_title('Rating vs. Revenue')

sns.histplot(x='Rating', data=data, bins=20, ax=axes[1, 0])
axes[1, 0].set_title('Histogram of Movie Ratings')

sns.lineplot(x='Year', y='Rating', data=data, ax=axes[1, 1])
axes[1, 1].set_title('Movie Ratings Over Time')

plt.tight_layout()
plt.show()



sns.barplot(x='Year', y='Votes', data=data, hue='Year', palette='bright', dodge=False)
plt.title("Votes By Year")
plt.legend([],[], frameon=False)  # Hide the legend
plt.show()

plt.hist(data['Revenue (Millions)'], bins=5, edgecolor='black')
plt.xlabel('Revenue (Millions)')
plt.ylabel('count')
plt.title('Revenue Distribution')
plt.show()

# sns.barplot(x='Runtime (Minutes)', y=top10_len.index, data=top10_len)

# sns.countplot(x='Year', data=data)
# plt.title("Number of Movies Per Year")
# plt.show()

# sns.barplot(x='Rating', y=top10_len.index, data=top10_len, hue='Director', dodge=False)
# plt.legend(bbox_to_anchor=(1.05,1),loc=2)

rating = data.groupby('Year')['Rating'].mean()
plt.plot(rating.index, rating.values, marker='o', color='b', linestyle='-')
plt.title('Average Movie Ratings Over the Years', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Average Rating', fontsize=12)
# Show grid and plot
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[184], line 43
#      37 plt.show()
#      41 fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 10))
# ---> 43 sns.countplot(x='Year', y='Votes', hue='Year', palette='bright', data=data, ax=axes[0, 0])
#      44 axes[0, 0].set_title('Votes By Year')
#      46 sns.scatterplot(x='Rating', y='Revenue (Millions)', data=data, ax=axes[0, 1])
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2629, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2627     y = 1 if list(x) else None
#    2628 elif x is not None and y is not None:
# -> 2629     raise TypeError("Cannot pass values for both `x` and `y`.")
#    2631 p = _CategoricalAggPlotter(
#    2632     data=data,
# ...

# %%
sns.barplot(x='Revenue (Millions)', y=top_10.index, data=top_10, hue='Title', dodge=False)
plt.title("Top 10 Highes Revenue Movie Titles")
plt.show()

sns.scatterplot(x="Rating", y="Revenue (Millions)", data=data)
sns.scatterplot(x="Rating", y="Runtime (Minutes)", data=data)

# %%
sns.barplot(x='Runtime (Minutes)', y=top10_len.index, data=top10_len)

sns.countplot(x='Year', data=data)
plt.title("Number of Movies Per Year")
plt.show()

sns.barplot(x='Rating', y=top10_len.index, data=top10_len, hue='Director', dodge=False)
plt.legend(bbox_to_anchor=(1.05,1),loc=2)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# Assuming 'data' is your DataFrame and 'counter_data' is your Counter object
counter_data = Counter({
        'Drama': 474,
        'Action': 289,
        'Comedy': 268,
        'Adventure': 249,
        'Thriller': 183,
        'Crime': 141,
        'Romance': 131,
        'Sci-Fi': 114,
        'Horror': 108,
        'Mystery': 99,
        'Fantasy': 98,
        'Biography': 71,
        'Family': 50,
        'Animation': 46,
        'History': 28,
        'Music': 16,
        'Sport': 16,
        'War': 12,
        'Western': 6,
        'Musical': 5
})

# Extract genres and frequencies
genres = list(counter_data.keys())
frequencies = list(counter_data.values())

# Create a figure with subplots
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(18, 12))

# Bar chart for genre distribution
axes[0, 0].bar(genres, frequencies, color='blue')
axes[0, 0].set_xlabel('Genre')
axes[0, 0].set_ylabel('Frequency')
axes[0, 0].set_title('Genre Distribution')
axes[0, 0].tick_params(axis='x', rotation=45)

# Count plot for Votes by Year (corrected)
sns.countplot(x='Year', hue='Year', palette='bright', data=data, ax=axes[0, 1])
axes[0, 1].set_title('Votes By Year')

# Scatter plot for Rating vs. Revenue
sns.scatterplot(x='Rating', y='Revenue (Millions)', data=data, ax=axes[0, 2])
axes[0, 2].set_title('Rating vs. Revenue')

# Histogram of Movie Ratings
sns.histplot(x='Rating', data=data, bins=20, ax=axes[1, 0])
axes[1, 0].set_title('Histogram of Movie Ratings')

# Line plot for Movie Ratings Over Time
sns.lineplot(x='Year', y='Rating', data=data, ax=axes[1, 1])
axes[1, 1].set_title('Movie Ratings Over Time')

# Bar plot for Votes By Year (without legend)
sns.barplot(x='Year', y='Votes', data=data, palette='bright', dodge=False, ax=axes[1, 2])
axes[1, 2].set_title("Votes By Year")
axes[1, 2].legend([],[], frameon=False)  # Hide the legend

# Histogram for Revenue Distribution
axes[2, 0].hist(data['Revenue (Millions)'], bins=5, edgecolor='black')
axes[2, 0].set_xlabel('Revenue (Millions)')
axes[2, 0].set_ylabel('Count')
axes[2, 0].set_title('Revenue Distribution')

# Line plot for Average Movie Ratings Over the Years
rating = data.groupby('Year')['Rating'].mean()
axes[2, 1].plot(rating.index, rating.values, marker='o', color='b', linestyle='-')
axes[2, 1].set_title('Average Movie Ratings Over the Years')
axes[2, 1].set_xlabel('Year')
axes[2, 1].set_ylabel('Average Rating')
axes[2, 1].grid(True)

# Hide the empty subplot (2, 2)
axes[2, 2].axis('off')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the combined plot
plt.show()
