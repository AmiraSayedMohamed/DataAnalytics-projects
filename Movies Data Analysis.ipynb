# %% [markdown]
# # Steps for Data Analysis:
#
#
# ---------------------------------
#   ##  1.Understand the Dataset:
# -------------------------
#
#         - Review each column in the dataset to understand its meaning.
#         - Identify the type of data in each column (e.g., numerical, categorical, text).
#    ----------------
#  ## 2.Data Cleaning:
#  ------------------
#
#     - Handle missing values (e.g., Revenue and Metascore have NaN values).
#     - Correct data types if needed (e.g., ensure 'Year' is an integer, 'Revenue' is a float).
#     - Remove any duplicates if present.
#
# ---------------------------------
#  ## 3.Exploratory Data Analysis (EDA):
# --------------------------------
#
#    ### Descripive Statistics:
#     - Summarize numerical data (mean, median, mode, etc.).
#     - Count unique values in categorical columns like Genre, Director, and Actors.
#    ### Correlations:
#     - Analyze the correlation between numerical variables (e.g., Rating vs. Revenue).
#    ### Outliers:
#     - Identify and investigate outliers in numerical columns like Revenue and Votes.
#
# --------------------------------------------------
#  ## 4.Formulate Questions:
#  -----------------------------
#
#    ### General Questions:
#     - What are the most common genres?
#     - Which directors and actors are most frequent in the top-ranked movies?
#     - What is the average runtime of movies?
#    ### Performance-Related Questions:
#     - How does movie rating correlate with revenue?
#     - Is there a relationship between runtime and rating?
#     - Which years produced the highest-grossing movies?
#    ### Trend Analysis:
#     - How have movie ratings changed over the years?
#     - What genres have the highest average revenue?
#
# -----------------------
#    ## 5.Extract Insights:
# -----------------------
#
#     - Determine the top genres and their performance metrics (e.g., average rating and revenue).
#     - Identify directors who consistently produce high-revenue movies.
#     - Analyze the effect of runtime on a movie’s rating and revenue.
#     - Evaluate the most profitable years and the trends in movie production.
#
# ----------------------------------------------------------------------------------
#   ## 6. Visualization (Graphs to Appear in Dashboard):
# -----------------------------------------------------
#
#    ### Histogram:
#     - Distribution of movie ratings.
#     - Distribution of revenues.
#     - Distribution of runtimes.
#    ### Bar Chart:
#     - Count of movies by genre.
#     - Average revenue per genre.
#     - Top directors based on average rating and revenue.
#    ### Scatter Plot:
#     - Rating vs. Revenue.
#     - Runtime vs. Rating.
#    ### Line Plot:
#     - Trends of movie ratings over the years.
#     - Trends of average revenue over the years.
#    ### Box Plot:
#     - Distribution of ratings and revenues by genre.
#    ### Heatmap:
#     - Correlation matrix of numerical variables (Rating, Votes, Revenue, Metascore).
#
#
#   ## 7.Dashboard Layout Using Subplots:
#
#    ### Top Row:
#         Left: Bar chart showing the count of movies by genre.
#         Right: Scatter plot of Rating vs. Revenue.
#    ### Middle Row:
#         Left: Histogram of movie ratings.
#         Right: Line plot showing trends of movie ratings over the years.
#    ### Bottom Row:
#     Left: Box plot showing the distribution of revenue by genre.
#     Right: Heatmap of the correlation matrix.
#
#
# # Insights to Extract:
#   ## Genre Popularity:
#        Identify which genres dominate the dataset in terms of both count and performance metrics like rating and revenue.
#   ## Director Impact:
#       Determine which directors are associated with higher ratings and revenue.
#   ## Yearly Trends:
#       Understand how the film industry has evolved in terms of movie quality (ratings) and profitability (revenue).
#   ## Runtime Analysis:
#       Evaluate whether longer or shorter movies tend to have higher ratings or revenue.

# %% [markdown]
# # 1.Import The necessary libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("tmdb-movies.csv")
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.shape
# Out:
# (10866, 21)

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
df.head(10)
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
# 5  281957  tt1663202    9.110700  135000000   532950503
# 6   87101  tt1340138    8.654359  155000000   440603537
# 7  286217  tt3659388    7.667400  108000000   595380321
# 8  211672  tt2293640    7.404165   74000000  1156730962
# 9  150540  tt2096673    6.326804  175000000   853708609
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
# 5                  The Revenant
# 6            Terminator Genisys
# 7                   The Martian
# 8                       Minions
# ...

# %%
df.tail(10)
# Out:
#           id    imdb_id  popularity  budget  revenue  \
# 10856  20277  tt0061135    0.140934       0        0
# 10857   5921  tt0060748    0.131378       0        0
# 10858  31918  tt0060921    0.317824       0        0
# 10859  20620  tt0060955    0.089072       0        0
# 10860   5060  tt0060214    0.087034       0        0
# 10861     21  tt0060371    0.080598       0        0
# 10862  20379  tt0060472    0.065543       0        0
# 10863  39768  tt0060161    0.065141       0        0
# 10864  21449  tt0061177    0.064317       0        0
# 10865  22293  tt0060666    0.035919   19000        0
#
#                                          original_title  \
# 10856                                The Ugly Dachshund
# 10857                                      Nevada Smith
# 10858  The Russians Are Coming, The Russians Are Coming
# 10859                                           Seconds
# 10860                               Carry On Screaming!
# ...

# %% [markdown]
# # 2. Get info about the data like data type, number of null values, names of the columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %% [markdown]
# # 3.Chech if there were any null values

# %%
print("Any Missing value?", df.isnull().values.any())
# Out:
# Any Missing value? True

# %%
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # 4.Get percentage of the missing values in columns

# %%
# Get percentage of the missing value in columns
per_missing = df.isnull().sum() * 100 / len(df)
per_missing
# Out:
# id                       0.000000
# imdb_id                  0.092030
# popularity               0.000000
# budget                   0.000000
# revenue                  0.000000
# original_title           0.000000
# cast                     0.699429
# homepage                72.979937
# director                 0.404933
# tagline                 25.989324
# keywords                13.740107
# overview                 0.036812
# runtime                  0.000000
# genres                   0.211669
# production_companies     9.479109
# release_date             0.000000
# vote_count               0.000000
# vote_average             0.000000
# release_year             0.000000
# budget_adj               0.000000
# revenue_adj              0.000000
# dtype: float64

# %% [markdown]
# # 5.drop rows where any null values

# %%
df = df.dropna(axis=0)

# %% [markdown]
# # 6.drop duplicated values

# %%
dup_data = df.duplicated().any()

# %%
print("Are there any duplicated values?", dup_data)
# Out:
# Are there any duplicated values? False

# %%
# but if there any duplicate values use this
df = df.drop_duplicates()
df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10724     668  tt0064757    1.778746    7000000    81974493
# 10759     948  tt0077651    1.198849     300000    70000000
# 10760    8469  tt0077975    1.157930    2700000   141000000
# 10817   13963  tt0077838    0.064029          0      321952
# 10819   16214  tt0077696    0.044675          0    78000000
#
#                         original_title  \
# 0                       Jurassic World
# 1                   Mad Max: Fury Road
# 2                            Insurgent
# 3         Star Wars: The Force Awakens
# 4                            Furious 7
# ...

# %% [markdown]
# # 7.statistical measure

# %%
df.describe()
# Out:
#                   id   popularity        budget       revenue      runtime  \
# count    1992.000000  1992.000000  1.992000e+03  1.992000e+03  1992.000000
# mean    71652.152108     1.316763  3.454924e+07  1.152153e+08   106.040161
# std     92355.883915     1.873563  5.061878e+07  2.202887e+08    29.234592
# min        11.000000     0.000620  0.000000e+00  0.000000e+00     0.000000
# 25%      9699.000000     0.384079  0.000000e+00  0.000000e+00    92.000000
# 50%     35112.500000     0.774223  1.500000e+07  2.578782e+07   102.000000
# 75%     83573.000000     1.538639  4.800000e+07  1.278787e+08   116.000000
# max    414419.000000    32.985763  4.250000e+08  2.781506e+09   705.000000
#
#         vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  1992.000000   1992.000000   1992.000000  1.992000e+03  1.992000e+03
# mean    643.616968      6.178614   2007.796687  3.627376e+07  1.302391e+08
# ...

# %%
df.isnull().sum()
# Out:
# id                      0
# imdb_id                 0
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# homepage                0
# director                0
# tagline                 0
# keywords                0
# overview                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# budget_adj              0
# revenue_adj             0
# dtype: int64

# %% [markdown]
# # 8.Remove outlier

# %%
# We check the outliers of every feature using boxplot
plt.figure(figsize=(15,7))
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
# Select only the numeric columns
numeric_df = df.select_dtypes(include=[float, int])

for col in numeric_df:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    upper_limit = q3 + (1.5 * iqr)
    lower_limit = q1 - (1.5 * iqr)
    new_df2 = df.loc[(df[col] <= upper_limit) & (df[col] >= lower_limit)]
print('before removing outliers: ', len(df))
print('after removing outliers: ', len(new_df2))
print('outliers:', len(df)-len(new_df2))
df = new_df2
# Out:
# before removing outliers:  1992
# after removing outliers:  1767
# outliers: 225

# %% [markdown]
# # 9.Display Title of The movie Having Runtime >= 180 Minutes

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
df[df['runtime']>=500]
# Out:
#           id    imdb_id  popularity     budget    revenue    original_title  \
# 1865  220903  tt1533395    0.102223          0          0              Life
# 2214  189197  tt0374463    0.757082  120000000          0       The Pacific
# 2722  331214  tt0185906    0.537593          0  125000000  Band of Brothers
#
#                                                    cast  \
# 1865                   David Attenborough|Oprah Winfrey
# 2214  James Badge Dale|Joseph Mazzello|Jon Seda|Asht...
# 2722  Damian Lewis|Ron Livingston|Frank John Hughes|...
#
#                                        homepage  \
# 1865   http://www.bbc.co.uk/programmes/b00lbpcy
# 2214  http://www.hbo.com/the-pacific/index.html
# 2722        http://www.hbo.com/band-of-brothers
#
#                                                director  \
# 1865          Martha Holmes|Simon Blakeney|Stephen Lyle
# 2214  Jeremy Podeswa|Tim Van Patten|David Nutter|Gra...
# 2722  Phil Alden Robinson|Richard Loncraine|Mikael S...
#
# ...

# %%
df[df['runtime']>=800]['original_title']
# Out:
# Series([], Name: original_title, dtype: object)

# %% [markdown]
# # 10.In Which Year There was the highest Average Voting

# %%
# Display first all columns we have to know which the name the vote column
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %% [markdown]
# # Highest Average Vote by Year:

# %%
highest_avg_vote_year = df.groupby('release_year')['vote_average'].mean().idxmax()
highest_avg_vote_value = df.groupby('release_year')['vote_average'].mean().max()

print(f"Year with the highest average vote: {highest_avg_vote_year}, Average Vote: {highest_avg_vote_value}")
# Out:
# Year with the highest average vote: 1975, Average Vote: 7.6

# %% [markdown]
# # Highest Average Vote by Director:

# %%
highest_avg_vote_director = df.groupby('director')['vote_average'].mean().idxmax()
highest_avg_vote_value = df.groupby('director')['vote_average'].mean().max()

print(f"Director with the highest average vote: {highest_avg_vote_director}, Average Vote: {highest_avg_vote_value}")
# Out:
# Director with the highest average vote: Damien Chazelle, Average Vote: 8.2

# %% [markdown]
# # Highest Average Vote by Genre:

# %%
highest_avg_vote_genre = df.groupby('genres')['vote_average'].mean().idxmax()
highest_avg_vote_value = df.groupby('genres')['vote_average'].mean().max()

print(f"Genre with the highest average vote: {highest_avg_vote_genre}, Average Vote: {highest_avg_vote_value}")
# Out:
# Genre with the highest average vote: Crime|Action, Average Vote: 8.1

# %% [markdown]
# #  Highest Average Vote Overall:

# %%
highest_avg_vote = df['vote_average'].max()
print(f"Highest average vote: {highest_avg_vote}")
# Out:
# Highest average vote: 8.2

# %%
# Group by release_year and calculate the mean of vote_average
average_votes_by_year = df.groupby('release_year')['vote_average'].mean().reset_index()

# Sort the years by average votes in descending order and select the top 5
top_5_years = average_votes_by_year.sort_values(by='vote_average', ascending=False).head(5)

# Plot the bar plot
sns.barplot(x='release_year', y='vote_average', data=top_5_years, palette='coolwarm', hue='vote_average')
plt.title("Top 5 Years with the Highest Average Votes")
plt.xlabel("Release Year")
plt.ylabel("Average Vote")
plt.show()

# %% [markdown]
# # 11.In Which Year There Was The Highest Average Revenue?

# %%
# to show the names of columns to know the name of the revenue columns
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
# Group by release_year and calculate the mean of revenue
average_revenue_by_year = df.groupby('release_year')['revenue'].mean().reset_index()

# Find the year with the highest average revenue
highest_avg_revenue_year = average_revenue_by_year.loc[average_revenue_by_year['revenue'].idxmax()]

print(f"The year with the highest average revenue is {highest_avg_revenue_year['release_year']} with an average revenue of {highest_avg_revenue_year['revenue']:.2f}.")
# Out:
# The year with the highest average revenue is 1996.0 with an average revenue of 88105877.36.

# %%
# Select the top 10 movies based on revenue
top10_revenue = df.nlargest(10, 'revenue')[['original_title', 'revenue']].set_index('original_title')

# Display the result
top10_revenue
# Out:
#                                     revenue
# original_title
# Mad Max: Fury Road                378436354
# Edge of Tomorrow                  370541256
# Gone Girl                         369330363
# Home                              368871007
# Noah                              362637473
# Hotel Transylvania                358375603
# Journey 2: The Mysterious Island  355692760
# The Maze Runner                   348319861
# The Smurfs 2                      347434178
# X-Men: First Class                344420111

# %%
# Plot the bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=top10_revenue['revenue'], y=top10_revenue.index, palette='viridis')

# Add titles and labels
plt.title('Top 10 Movies by Revenue', fontsize=16)
plt.xlabel('Revenue (in billions)', fontsize=12)
plt.ylabel('Movie Title', fontsize=12)

# Show the plot
plt.show()
# Out:
# C:\Users\amira\AppData\Local\Temp\ipykernel_15380\2978188896.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top10_revenue['revenue'], y=top10_revenue.index, palette='viridis')

# %% [markdown]
# # .Display Top 10 Lengthy Movies Title and Runtime

# %%
# 13.Display Top 10 Lengthy Movies Title and Runtime
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
top10_len = df.nlargest(10, 'runtime')[['original_title', 'runtime']].set_index('original_title')
top10_len
# Out:
#                                     runtime
# original_title
# Band of Brothers                        705
# The Pacific                             540
# Life                                    500
# Mildred Pierce                          336
# Frank Herbert's Dune                    292
# Klondike                                285
# Kill Bill: The Whole Bloody Affair      247
# Zeitgeist: Moving Forward               201
# Magnolia                                188
# History of the Eagles                   186

# %%
sns.barplot(x='runtime', y=top10_len.index, data=top10_len)
# Out:
# <Axes: xlabel='runtime', ylabel='original_title'>

# %% [markdown]
# # 14. Display Number of Movies Per Yea

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
df['release_year'].value_counts()
# Out:
# release_year
# 2011    205
# 2010    193
# 2009    178
# 2015    149
# 2014    137
# 2008    131
# 2012    129
# 2007    121
# 2013    113
# 2006     85
# 2005     68
# 2004     39
# 2003     36
# 2002     25
# 2000     18
# 1999     16
# 1996     14
# 2001     13
# 1998     11
# 1997      8
# 1993      8
# 1995      7
# 1994      6
# 1987      6
# 1981      4
# 1990      4
# 1988      4
# 1979      4
# 1971      3
# 1989      3
# 1983      3
# 1984      3
# 1985      3
# 1978      3
# 1982      2
# 1991      2
# 1992      2
# 1976      2
# 1986      2
# 1974      1
# 1975      1
# 1964      1
# 1980      1
# 1961      1
# 1977      1
# 1970      1
# Name: count, dtype: int64

# %%
sns.countplot(x='release_year', data=df)
plt.title("Number of Movies Per Year")
plt.xticks(rotation=90, ha='right',fontsize=6)
plt.show()

# %% [markdown]
# # 15.Find Most Popular Movie Title(Highes Revenue)

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
df['revenue'].max()
# Out:
# 378436354

# %%
df[df['revenue'].max()==df['revenue']]['original_title']
# Out:
# 1    Mad Max: Fury Road
# Name: original_title, dtype: object

# %% [markdown]
# -----------------------------------------
# The movie(Mad Max: Fury Road
# ) hae highest revenue
# ------------------------------------------

# %% [markdown]
# # 16.Does Voting affect Revenue?

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Scatter plot of vote_average vs. revenue
plt.scatter(df['vote_average'], df['revenue'], alpha=0.5, color='b')

# Add titles and labels
plt.title('Voting vs. Revenue', fontsize=16)
plt.xlabel('Average Vote Rating', fontsize=12)
plt.ylabel('Revenue', fontsize=12)

# Show grid and plot
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Group by 'release_year' and calculate the average rating
voting = df.groupby('release_year')['vote_average'].mean()

# Plot the data
plt.plot(voting.index, voting.values, marker='o', color='b', linestyle='-')

# Add titles and labels
plt.title('Average Movie Voting Over the Years', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Average Voting', fontsize=12)

# Show the plot
plt.show()

# %% [markdown]
# # 17.Find Unique Values From Genre

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
df['genres']
# Out:
# 1        Action|Adventure|Science Fiction|Thriller
# 2               Adventure|Science Fiction|Thriller
# 11        Science Fiction|Fantasy|Action|Adventure
# 12                           Drama|Science Fiction
# 13                   Action|Comedy|Science Fiction
#                            ...
# 10567                                Drama|History
# 10657                        Comedy|Drama|Thriller
# 10759                              Horror|Thriller
# 10817                            Documentary|Music
# 10819                                Action|Comedy
# Name: genres, Length: 1767, dtype: object

# %%
list1=[]
for value in df['genres']:
    list1.append(value.split('|'))

# %%
list1
# Out:
# [['Action', 'Adventure', 'Science Fiction', 'Thriller'],
#  ['Adventure', 'Science Fiction', 'Thriller'],
#  ['Science Fiction', 'Fantasy', 'Action', 'Adventure'],
#  ['Drama', 'Science Fiction'],
#  ['Action', 'Comedy', 'Science Fiction'],
#  ['Crime', 'Drama', 'Mystery', 'Western'],
#  ['Crime', 'Action', 'Thriller'],
#  ['Action', 'Family', 'Science Fiction', 'Adventure', 'Mystery'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Thriller', 'History'],
#  ['Action', 'Science Fiction', 'Thriller'],
#  ['Mystery', 'Drama'],
#  ['Crime', 'Action', 'Science Fiction'],
#  ['Adventure', 'Horror', 'Comedy'],
#  ['Drama', 'Thriller'],
#  ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Music'],
#  ['Fantasy', 'Action', 'Adventure'],
#  ['Fantasy', 'Drama', 'Romance'],
#  ['Action', 'Adventure', 'Science Fiction'],
#  ['Fantasy', 'Comedy', 'Animation', 'Science Fiction', 'Family'],
#  ['Thriller', 'Comedy', 'Drama', 'Romance', 'Science Fiction'],
# ...

# %%
one_d = []
for item in list1:
    for item1 in item:
        one_d.append(item1)

# %%
one_d
# Out:
# ['Action',
#  'Adventure',
#  'Science Fiction',
#  'Thriller',
#  'Adventure',
#  'Science Fiction',
#  'Thriller',
#  'Science Fiction',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Science Fiction',
#  'Action',
#  'Comedy',
#  'Science Fiction',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Western',
#  'Crime',
#  'Action',
#  'Thriller',
#  'Action',
#  'Family',
#  'Science Fiction',
#  'Adventure',
#  'Mystery',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Thriller',
#  'History',
#  'Action',
#  'Science Fiction',
#  'Thriller',
#  'Mystery',
#  'Drama',
#  'Crime',
#  'Action',
#  'Science Fiction',
#  'Adventure',
#  'Horror',
#  'Comedy',
#  'Drama',
#  'Thriller',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Music',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Drama',
#  'Romance',
#  'Action',
#  'Adventure',
#  'Science Fiction',
#  'Fantasy',
#  'Comedy',
#  'Animation',
# ...

# %%
uni_list=[]
for item in one_d:
    if item not in uni_list:
        uni_list.append(item)

# %%
uni_list
# Out:
# ['Action',
#  'Adventure',
#  'Science Fiction',
#  'Thriller',
#  'Fantasy',
#  'Drama',
#  'Comedy',
#  'Crime',
#  'Mystery',
#  'Western',
#  'Family',
#  'History',
#  'Horror',
#  'Animation',
#  'Romance',
#  'Music',
#  'War',
#  'Documentary',
#  'TV Movie',
#  'Foreign']

# %%
len(uni_list)
# Out:
# 20

# %% [markdown]
# # 18.How many Films of Each Genre were made ?

# %%
one_d =[]
for item in list1:
    for item1 in item:
        one_d.append(item1)

# %%
one_d
# Out:
# ['Action',
#  'Adventure',
#  'Science Fiction',
#  'Thriller',
#  'Adventure',
#  'Science Fiction',
#  'Thriller',
#  'Science Fiction',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Science Fiction',
#  'Action',
#  'Comedy',
#  'Science Fiction',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Western',
#  'Crime',
#  'Action',
#  'Thriller',
#  'Action',
#  'Family',
#  'Science Fiction',
#  'Adventure',
#  'Mystery',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Thriller',
#  'History',
#  'Action',
#  'Science Fiction',
#  'Thriller',
#  'Mystery',
#  'Drama',
#  'Crime',
#  'Action',
#  'Science Fiction',
#  'Adventure',
#  'Horror',
#  'Comedy',
#  'Drama',
#  'Thriller',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Music',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Drama',
#  'Romance',
#  'Action',
#  'Adventure',
#  'Science Fiction',
#  'Fantasy',
#  'Comedy',
#  'Animation',
# ...

# %%
from collections import Counter

# %%
Counter(one_d)
# Out:
# Counter({'Drama': 797,
#          'Comedy': 581,
#          'Thriller': 516,
#          'Action': 412,
#          'Romance': 273,
#          'Horror': 267,
#          'Crime': 245,
#          'Science Fiction': 229,
#          'Adventure': 218,
#          'Family': 168,
#          'Mystery': 138,
#          'Fantasy': 137,
#          'Animation': 122,
#          'Documentary': 93,
#          'Music': 66,
#          'History': 54,
#          'War': 40,
#          'Western': 18,
#          'TV Movie': 16,
#          'Foreign': 6})

# %%
counter_data = Counter({
        'Drama': 838,
         'Comedy': 640,
         'Thriller': 575,
         'Action': 532,
         'Adventure': 361,
         'Science Fiction': 291,
         'Romance': 291,
         'Horror': 273,
         'Crime': 262,
         'Family': 233,
         'Fantasy': 202,
         'Animation': 170,
         'Mystery': 148,
         'Documentary': 93,
         'Music': 72,
         'History': 56,
         'War': 44,
         'Western': 20,
         'TV Movie': 16,
         'Foreign': 6
})

# Extract genres and frequencies
genres = list(counter_data.keys())
frequencies = list(counter_data.values())

# Create the bar chart
plt.figure(figsize=(12, 6))
plt.bar(genres, frequencies, color='blue')
plt.xlabel('Genre')
plt.ylabel('Frequency')
plt.title('Genre Distribution')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 19. Is there a relationship between films and revenue

# %%
import matplotlib.pyplot as plt

# Group the data by release year and calculate the number of films and total revenue per year
films_per_year = df.groupby('release_year').size()  # Number of films per year
revenue_per_year = df.groupby('release_year')['revenue'].sum()  # Total revenue per year

# Create a bar plot for the number of films and line plot for revenue on the same graph
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:blue'
ax1.set_xlabel('Year')
ax1.set_ylabel('Number of Films', color=color)
ax1.bar(films_per_year.index, films_per_year.values, color=color, alpha=0.6)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # Create a second y-axis
color = 'tab:red'
ax2.set_ylabel('Total Revenue', color=color)
ax2.plot(revenue_per_year.index, revenue_per_year.values, color=color)
ax2.tick_params(axis='y', labelcolor=color)

plt.title('Relation Between Number of Films and Revenue')
plt.grid(True)
plt.show()

# %% [markdown]
# # 20.what is the Top 10 Directories by voting

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by director and calculate the average vote
top_directors = df.groupby('director')['vote_average'].mean()

# Sort the directors by average vote in descending order and select the top 10
top_10_directors = top_directors.sort_values(ascending=False).head(10)

# Plot the top 10 directors by average vote
plt.figure(figsize=(10, 6))
plt.barh(top_10_directors.index, top_10_directors.values, color='purple')

# Add titles and labels
plt.title('Top 10 Directors by Average Voting', fontsize=16)
plt.xlabel('Average Vote', fontsize=12)
plt.ylabel('Director', fontsize=12)

# Invert the y-axis to have the highest-rated director at the top
plt.gca().invert_yaxis()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sort the DataFrame by revenue to get the top 5 movies
top_5_movies = df.sort_values(by='revenue', ascending=False).head(5)

# Extract the relevant information
titles = top_5_movies['original_title']
revenues = top_5_movies['revenue']
genres = top_5_movies['genres']

# Create a bar plot to visualize the top 5 movies' revenue and genres
plt.figure(figsize=(12, 8))

# Bar plot for revenue
sns.barplot(x=revenues, y=titles, palette='Blues_d')

# Add title and labels
plt.title('Top 5 Movies by Revenue', fontsize=20)
plt.xlabel('Revenue', fontsize=16)
plt.ylabel('Movie Title', fontsize=16)

# Display genres as text annotations
for i in range(len(genres)):
    plt.text(revenues.iloc[i], i, f'Genre: {genres.iloc[i]}', ha='left', va='center', fontsize=12, color='black')

# Show the plot
plt.show()
# Out:
# C:\Users\amira\AppData\Local\Temp\ipykernel_15380\2100962955.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=revenues, y=titles, palette='Blues_d')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a figure with multiple subplots
plt.figure(figsize=(45, 25))  # Adjust the size to fit all subplots

# Subplot 1: Top 10 Years with the Highest Average Revenue
plt.subplot(5, 3, 1)
sns.barplot(x='release_year', y='revenue', data=top_10_years, palette='coolwarm')
plt.title("Top 10 Years with the Highest Average Revenue", fontsize=40)
plt.xlabel("Release Year", fontsize=30)
plt.ylabel("Average Revenue", fontsize=30)

# Subplot 2: Voting vs. Revenue
plt.subplot(5, 3, 2)
plt.scatter(df['vote_average'], df['revenue'], alpha=0.5, color='b')
plt.title('Voting vs. Revenue', fontsize=40)
plt.xlabel('Average Voting', fontsize=30)
plt.ylabel('Revenue', fontsize=30)
plt.grid(True)

# Subplot 3: Average Movie Voting Over the Years
plt.subplot(5, 3, 3)
plt.plot(rating.index, rating.values, marker='o', color='b', linestyle='-')
plt.title('Average Movie Voting Over the Years', fontsize=40)
plt.xlabel('Year', fontsize=30)
plt.ylabel('Average Rating', fontsize=30)

# Subplot 4: Top 5 Years with the Highest Average Votes
plt.subplot(5, 3, 4)
sns.barplot(x='release_year', y='vote_average', data=top_5_years, palette='viridis')
plt.title("Top 5 Years with the Highest Average Votes", fontsize=40)
plt.xlabel("Release Year", fontsize=30)
plt.ylabel("Average Vote", fontsize=30)

# Subplot 5: Number of Movies Per Year
plt.subplot(5, 3, 5)
sns.countplot(x='release_year', data=df)
plt.title("Number of Movies Per Year", fontsize=40)
plt.xticks(rotation=90, ha='right', fontsize=12)

# Subplot 6: Top 10 Movies by Revenue
plt.subplot(5, 3, 6)
sns.barplot(x=top10_revenue['revenue'], y=top10_revenue.index, palette='viridis')
plt.title('Top 10 Movies by Revenue', fontsize=40)
plt.xlabel('Revenue (in billions)', fontsize=30)
plt.ylabel('Movie Title', fontsize=30)

# Subplot 7: Top 10 Movies by Length
plt.subplot(5, 3, 7)
sns.barplot(x='runtime', y=top10_len.index, data=top10_len)
plt.title('Top 10 Movies by Length', fontsize=40)
plt.xlabel('Runtime', fontsize=30)
plt.ylabel('Movie Title', fontsize=30)

# Subplot 8: Relationship Between Runtime and Revenue
plt.subplot(5, 3, 8)
plt.scatter(df['runtime'], df['revenue'], alpha=0.5, color='green')
plt.title('Relationship Between Runtime and Revenue', fontsize=40)
plt.xlabel('Runtime (minutes)', fontsize=30)
plt.ylabel('Revenue', fontsize=30)
plt.grid(True)

# Subplot 9: Total Revenue Over the Years
# Group the data by release year and calculate the total revenue per year
revenue_per_year = df.groupby('release_year')['revenue'].sum()
# Create a line plot for the revenue over the years
plt.subplot(5, 3, 9)
plt.plot(revenue_per_year.index, revenue_per_year.values, marker='o', color='blue', linestyle='-')
# Adding title and labels
plt.title('Total Revenue Over the Years', fontsize=40)
plt.xlabel('Year', fontsize=30)
plt.ylabel('Total Revenue', fontsize=30)
# Adding grid for better readability
plt.grid(True)

# Subplot 10: Genre Distribution
plt.subplot(5, 3, 10)
# Sort the DataFrame by revenue to get the top 5 movies
top_5_movies = df.sort_values(by='revenue', ascending=False).head(5)

# Extract the relevant information
titles = top_5_movies['original_title']
revenues = top_5_movies['revenue']
genres = top_5_movies['genres']

# Bar plot for revenue
sns.barplot(x=revenues, y=titles, palette='Blues_d')

# Add title and labels
plt.title('Top 5 Movies by Revenue', fontsize=20)
plt.xlabel('Revenue', fontsize=16)
plt.ylabel('Movie Title', fontsize=16)

# Display genres as text annotations
for i in range(len(genres)):
    plt.text(revenues.iloc[i], i, f'Genre: {genres.iloc[i]}', ha='left', va='center', fontsize=12, color='black')


# Subplot 11: Relation Between Number of Films and Revenue
plt.subplot(5, 3, 11)
films_per_year = df.groupby('release_year').size()  # Number of films per year
revenue_per_year = df.groupby('release_year')['revenue'].sum()  # Total revenue per year

color = 'tab:blue'
ax1 = plt.gca()
ax1.set_xlabel('Year', fontsize=30)
ax1.set_ylabel('Number of Films', color=color, fontsize=30)
ax1.bar(films_per_year.index, films_per_year.values, color=color, alpha=0.6)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # Create a second y-axis
color = 'tab:red'
ax2.set_ylabel('Total Revenue', color=color, fontsize=30)
ax2.plot(revenue_per_year.index, revenue_per_year.values, color=color)
ax2.tick_params(axis='y', labelcolor=color)

plt.title('Relation Between Number of Films and Revenue', fontsize=40)
plt.grid(True)

# Subplot 12: Top 10 Directors by Average Voting
plt.subplot(5, 3, 12)
top_directors = df.groupby('director')['vote_average'].mean()
top_10_directors = top_directors.sort_values(ascending=False).head(10)
plt.barh(top_10_directors.index, top_10_directors.values, color='purple')
plt.title('Top 10 Directors by Average Voting', fontsize=40)
plt.xlabel('Average Vote', fontsize=30)
plt.ylabel('Director', fontsize=30)
plt.gca().invert_yaxis()  # Highest rated director at the top

# Adjust the layout
plt.tight_layout()

# Show the entire figure with all subplots
plt.show()
# Out:
# C:\Users\amira\AppData\Local\Temp\ipykernel_15380\2223075811.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='release_year', y='revenue', data=top_10_years, palette='coolwarm')
# C:\Users\amira\AppData\Local\Temp\ipykernel_15380\2223075811.py:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='release_year', y='vote_average', data=top_5_years, palette='viridis')
# C:\Users\amira\AppData\Local\Temp\ipykernel_15380\2223075811.py:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# voting affecting revenue when voting increase became between (5 and 8) , revenue increase << so we need to increase voting
#
# ------------------------------------------------
#
# The director who has the largest average vote:
# Damien Chazelle, Average Vote: 8.2
#
# ----------------------------------------------------
#
# Highest average vote by genre:   Crime|Action, Average Vote: 8.1
#
# -----------------------------------------------------------
#
# the revenue increase then the runtime is 100 min
#
# ------------------------------------------------------------
#
# increasing the number of films increase the revenue
#
# ---------------------------------------------------------
#
#
#
# ----------------------------------------------------
#
# the top 10 movie based on revenue:
# original_title	            revenue
# Mad Max: Fury Road	       378436354
# Edge of Tomorrow            370541256
# Gone Girl	                369330363
# Home	                   368871007
# Noah	                   362637473
# Hotel Transylvania	         358375603
# Journey 2: The Mysterious Island	355692760
# The Maze Runner	              348319861
# The Smurfs 2	          347434178
# X-Men: First Class	     344420111
#
# ------------------------------------------------------------------------
#
# The year that has highest Average vote is : 1975 year , 7.6 vote
#
# --------------------------------------------------------
#
# Drama films has the highest number of films per year  then(comedy, thriller, Action, Adventure)
#
# -----------------------------------------------------------
#
# The larges runtime film is 705 min:
#  name : Band of Brothers
# director: Phil Alden Robinson|Richard Loncraine|Mikael S
# genre: Action|Drama|War
#
# ------------------------------------------------------------
#
# The highest average vote Overall:   8.2
#
# ------------------------------------------------------
#
# the year that has the highes avergae revenue: 1996 with revenue of 88105877.36
#
# -----------------------------------------------------------
#
# highest revenue: 378436354 ,     Mad Max: Fury Road
#
# ------------------------------------------------------
#
# the voting of films decrease when year increase

# %% [markdown]
# # Insights we can conclude

# %% [markdown]
# when voting increase revenue increase in range voting from (5 to 9) so we need to increase voting
#
# we get high revenue from action and adventures movies
#
# use the top 10 ten directories to increase voting
#
# increase the number of films will increase revenue
#
# make runtime at 100 min will increase revenue
